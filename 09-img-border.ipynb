# %%
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np

# %%
# duong dan anh
my_dir = 'C:/Users/Admin/Documents/CVs/img/'
my_path = my_dir + "2.jpg";

# doc anh
img = Image.open(my_path)
plt.figure()
#show anh
plt.imshow(img)

# %%
# doc va show anh xam
img_gray = img.convert('L')
#hien thi anh tren truc toa do
plt.imshow(img_gray, cmap='gray')

# lam noi bat duong bien anh
# tao khung cho hinh ve moi
plt.figure()
plt.gray()
plt.contour(img_gray, origin="image")
plt.show()
